# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize

# %%
df = pd.read_parquet('./food_data.parquet', engine= 'auto')
df.head()
# Out:
#       shop_id                 shop_name  \
# 0  1415675181              Freezy Fresh
# 1  1658405839              Korean Jjang
# 2   477718102  Chocomory Official Store
# 3  1495464819     Mayora Official Store
# 4  1675639818                Hejo Fresh
#
#                                         name_product  price_product  rating  \
# 0            Pastel Goreng Kulit Renyah Frozen 5 pcs        38000.0       5
# 1  D KING BONIBOL 250 GR ISI 1 PCS BISKUIT SALUT ...        17000.0       5
# 2             Chocomory Choco Pie Isi 20 540 Gr 1 Pc        78000.0       5
# 3                             Better Big Pack 120 Gr         8650.0       5
# 4      Hejo Pempek Dos Vegetarian Pempek Kates Vegan        27900.0       5
#
#    rating_average       location  count_review
# 0             4.9         Bekasi           245
# 1             4.9  Jakarta Barat           213
# 2             4.9          Bogor          1117
# 3             5.0  Jakarta Barat          1736
# 4             4.9  Jakarta Pusat           373

# %%
df.columns
# Out:
# Index(['shop_id', 'shop_name', 'name_product', 'price_product', 'rating',
#        'rating_average', 'location', 'count_review'],
#       dtype='object')

# %%
#encoding
bow = CountVectorizer(stop_words='english', tokenizer=word_tokenize)
bank = bow.fit_transform(df.name_product)

# %%
idx = 0

# %%
content = df.loc[idx, 'name_product']
content
# Out:
# 'Pastel Goreng Kulit Renyah Frozen 5 pcs'

# %%
code = bow.transform([content])
code
# Out:
# <1x837 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
#Product Search
from sklearn.metrics.pairwise import cosine_distances

# %%
dist = cosine_distances(code, bank)
dist
# Out:
# array([[3.33066907e-16, 8.95171516e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 6.58118271e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 7.81782110e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.98984746e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.66369379e-01, 8.95171516e-01,
#         8.45696650e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 7.81782110e-01,
#         1.00000000e+00, 1.00000000e+00, 8.98984746e-01, 1.00000000e+00,
#         8.66369379e-01, 9.05508882e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.80477139e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.30969149e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.74011842e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.74011842e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         9.08330150e-01, 8.45696650e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 8.80477139e-01,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.74011842e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 8.74011842e-01, 1.00000000e+00,
#         8.45696650e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.45696650e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.66369379e-01, 1.00000000e+00, 1.00000000e+00, 8.98984746e-01,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 8.66369379e-01, 1.00000000e+00, 8.90891055e-01,
#         9.10912919e-01, 8.45696650e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 8.95171516e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 8.86039424e-01, 8.66369379e-01, 1.00000000e+00,
#         1.00000000e+00, 8.95171516e-01, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.66369379e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 7.72078847e-01, 1.00000000e+00,
#         1.00000000e+00, 6.91393300e-01, 1.00000000e+00, 1.00000000e+00,
#         8.90891055e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.57142857e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         8.74011842e-01, 1.00000000e+00, 7.32738758e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 8.80477139e-01,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 7.60954278e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 8.74011842e-01,
#         8.45696650e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         9.02409993e-01, 1.00000000e+00, 8.74011842e-01, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00]])

# %%
#10 items
rec_idx = dist.argsort()[0, 1:11]
rec_idx
# Out:
# array([  6, 177, 194, 226, 174,  43,  14,  66,  97,  24], dtype=int64)

# %%
df.loc[rec_idx]
# Out:
#         shop_id            shop_name  \
# 6    1881353462         Korean Jjang
# 177  1566626076         Freezy Fresh
# 194  2091028132         Freezy Fresh
# 226   589082146          gerai nuget
# 174  1768870580            SmallFood
# 43   1377268397  Dimsum 49 Rawamagun
# 14    796812309      Dua Coffee Shop
# 66    987903935    RICARAJA OFFICIAL
# 97    812019147       pempekberingin
# 24   1719573818           MD GROCERY
#
#                                           name_product  price_product  rating  \
# 6    CIMOL LELEH KEJU ISI 20 PCS FROZEN CEMILAN INS...        28000.0       5
# 177                     Potato Moza Ball frozen 10 pcs        33000.0       5
# 194                                      Frozen Combro        69500.0       5
# 226  Pitsa goreng rasa keju isi 6 pizza pigo frozen...        24000.0       5
# 174  15 Pcs Siomay Somay Ikan Frozen Food Cemilan A...        28500.0       5
# 43   DIMSUM 49 RAWAMANGUN ISI 100 PCS DIMSUM HALAL ...         1999.0       5
# 14                                 Risoles Mayo Frozen        30000.0       5
# 66                        FROZEN FOOD AYAM WOKU Vacuum        55000.0       5
# 97               Pempek Kulit Beringin Vacum Isi 10Pcs        66000.0       5
# 24                        MILO ENERGY CUBE isi 100 Pcs        65000.0       5
#
#      rating_average           location  count_review
# 6               4.8      Jakarta Barat           680
# 177             4.8             Bekasi           145
# 194             5.0             Bekasi            67
# 226             4.9             Bekasi           151
# 174             4.6  Tangerang Selatan           103
# 43              5.0      Jakarta Timur           888
# 14              4.8    Jakarta Selatan           306
# 66              4.6      Jakarta Utara            26
# 97              5.0      Jakarta Barat           311
# 24              4.9              Bogor          1227

# %%
class RecommenderSystem :
    def __init__(self, df, content_col):
        self.df = pd.read_parquet(df)
        self.content_col = content_col
        self.encoder = None
        self.bank = None
        
    def fit(self):
        self.encoder = CountVectorizer(stop_words='english', tokenizer=word_tokenize)
        self.bank = self.encoder.fit_transform(self.df[self.content_col])
        
    def transform(self, idx, topr=10):
        content = df.loc[idx, self.content_col]
        code = self.encoder.transform([content])
        dist = cosine_distances(code, self.bank)
        rec_idx = dist.argsort()[0, 1:(topr+1)]
        return self.df.loc[rec_idx]

# %%
recsys = RecommenderSystem('./food_data.parquet', content_col='name_product')
recsys.fit()

# %%
# 1 = D king bonibol
recsys.transform(1)
# Out:
#         shop_id                 shop_name  \
# 23   1658426574              Korean Jjang
# 132  2069774457       Rezeki Fresh Market
# 2     477718102  Chocomory Official Store
# 5     581813548  Chocomory Official Store
# 262  2096274472         Super Grosir Mama
# 202  1605352046                Ferry Fish
# 38   1520792374              Freezy Fresh
# 278   830629871        Japfa Best Jakarta
# 180  2047279761               Plaza Korea
# 24   1719573818                MD GROCERY
#
#                                           name_product  price_product  rating  \
# 23   D KING BONIBOL 1 DUS ISI 4 PCS BISKUIT SALUT C...        67200.0       5
# 132                 Kinder Bueno T2 Coklat 43 gr 2 Pcs        14500.0       5
# 2               Chocomory Choco Pie Isi 20 540 Gr 1 Pc        78000.0       5
# 5       Chocomory Cookies Cream Pie Isi 20 540 Gr 1 Pc        78000.0       5
# 262                   Biskuit Oatbits Vitafruit 110 gr         6950.0       5
# 202                          Piscok Meler Coklat Isi 8        11500.0       5
# 38                    Lotus Biscoff Caramelised 250 gr        39800.0       5
# 278                       Pempek Seafood Lovers 250 gr        16500.0       5
# 180  MOMOGI STICK 1 BOX ISI 20 PCS CEMILAN EKSTRUDA...         9450.0       5
# 24                        MILO ENERGY CUBE isi 100 Pcs        65000.0       5
#
#      rating_average           location  count_review
# 23              4.8      Jakarta Barat           364
# 132             5.0      Jakarta Barat            41
# 2               4.9              Bogor          1117
# 5               4.9              Bogor           671
# 262             4.9    Jakarta Selatan            38
# 202             4.8  Tangerang Selatan           155
# 38              5.0             Bekasi            95
# 278             4.9     Kab. Tangerang           725
# 180             4.8      Jakarta Barat           202
# 24              4.9              Bogor          1227
